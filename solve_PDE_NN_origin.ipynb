# %% [markdown]
# ## Problem Statement
#
# We have been given a PDE: du/dx=2du/dt+u
# and boundary condition: u(x,0)=6e^(-3x)
#
# - Independent variables: x,t (input)
# - Dependent variables: u (outputs)
#
#
# We have to find out u(x,t) for all x in range [0,2] and t in range [0,1]
#
#
# When we solved this problem analytically, we found the solution: u(x,t) = 6e^(-3x-2t)
#
#
# Our f is f = du/dx - 2du/dt - u

# %%
import torch
import torch.nn as nn
from torch.autograd import Variable
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
import numpy as np

# %%
# We consider Net as our solution u_theta(x,t)

"""
When forming the network, we have to keep in mind the number of inputs and outputs
In ur case: #inputs = 2 (x,t)
and #outputs = 1

You can add ass many hidden layers as you want with as many neurons.
More complex the network, the more prepared it is to find complex solutions, but it also requires more data.

Let us create this network:
min 5 hidden layer with 5 neurons each.
"""

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.hidden_layer1 = nn.Linear(2,5)
        self.hidden_layer2 = nn.Linear(5,5)
        self.hidden_layer3 = nn.Linear(5,5)
        self.hidden_layer4 = nn.Linear(5,5)
        self.hidden_layer5 = nn.Linear(5,5)
        self.output_layer = nn.Linear(5,1)

    def forward(self, x,t):
        print(x.shape,t.shape)
        inputs = torch.cat([x,t],axis=1) # combined two arrays of 1 columns each to one array of 2 columns
        print(inputs.shape)
        layer1_out = torch.sigmoid(self.hidden_layer1(inputs))
        layer2_out = torch.sigmoid(self.hidden_layer2(layer1_out))
        layer3_out = torch.sigmoid(self.hidden_layer3(layer2_out))
        layer4_out = torch.sigmoid(self.hidden_layer4(layer3_out))
        layer5_out = torch.sigmoid(self.hidden_layer5(layer4_out))
        output = self.output_layer(layer5_out) ## For regression, no activation is used in output layer
        return output

# %%
### (2) Model
net = Net()
net = net.to(device)
mse_cost_function = torch.nn.MSELoss() # Mean squared error
optimizer = torch.optim.Adam(net.parameters())

# %%
## PDE as loss function. Thus would use the network which we call as u_theta
def f(x,t, net):
    u = net(x,t) # the dependent variable u is given by the network based on independent variables x,t
    ## Based on our f = du/dx - 2du/dt - u, we need du/dx and du/dt
    u_x = torch.autograd.grad(u.sum(), x, create_graph=True)[0]
    u_t = torch.autograd.grad(u.sum(), t, create_graph=True)[0]
    pde = u_x - 2*u_t - u
    return pde

# %%
## Data from Boundary Conditions
# u(x,0)=6e^(-3x)
## BC just gives us datapoints for training

# BC tells us that for any x in range[0,2] and time=0, the value of u is given by 6e^(-3x)
# Take say 500 random numbers of x
x_bc = np.random.uniform(low=0.0, high=2.0, size=(500,1))
t_bc = np.zeros((500,1))
# compute u based on BC
u_bc = 6*np.exp(-3*x_bc)

# %%
### (3) Training / Fitting
iterations = 20000
previous_validation_loss = 99999999.0
for epoch in range(iterations):
    optimizer.zero_grad() # to make the gradients zero
    
    # Loss based on boundary conditions
    pt_x_bc = Variable(torch.from_numpy(x_bc).float(), requires_grad=False).to(device)
    pt_t_bc = Variable(torch.from_numpy(t_bc).float(), requires_grad=False).to(device)
    pt_u_bc = Variable(torch.from_numpy(u_bc).float(), requires_grad=False).to(device)
    
    net_bc_out = net(pt_x_bc, pt_t_bc) # output of u(x,t)
    mse_u = mse_cost_function(net_bc_out, pt_u_bc)
    
    # Loss based on PDE
    x_collocation = np.random.uniform(low=0.0, high=2.0, size=(500,1))
    t_collocation = np.random.uniform(low=0.0, high=1.0, size=(500,1))
    all_zeros = np.zeros((500,1))
    
    
    pt_x_collocation = Variable(torch.from_numpy(x_collocation).float(), requires_grad=True).to(device)
    pt_t_collocation = Variable(torch.from_numpy(t_collocation).float(), requires_grad=True).to(device)
    pt_all_zeros = Variable(torch.from_numpy(all_zeros).float(), requires_grad=False).to(device)
    
    f_out = f(pt_x_collocation, pt_t_collocation, net) # output of f(x,t)
    mse_f = mse_cost_function(f_out, pt_all_zeros)
    
    # Combining the loss functions
    loss = mse_u + mse_f
    
    
    loss.backward() # This is for computing gradients using backward propagation
    optimizer.step() # This is equivalent to : theta_new = theta_old - alpha * derivative of J w.r.t theta

    with torch.autograd.no_grad():
    	print(epoch,"Traning Loss:",loss.data)
# Out:
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 0 Traning Loss: tensor(2.8905)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 1 Traning Loss: tensor(2.8831)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 2 Traning Loss: tensor(2.8758)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 3 Traning Loss: tensor(2.8686)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 4 Traning Loss: tensor(2.8615)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 5 Traning Loss: tensor(2.8545)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6 Traning Loss: tensor(2.8475)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 7 Traning Loss: tensor(2.8407)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 8 Traning Loss: tensor(2.8339)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 9 Traning Loss: tensor(2.8272)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 10 Traning Loss: tensor(2.8206)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 11 Traning Loss: tensor(2.8141)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 12 Traning Loss: tensor(2.8076)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 13 Traning Loss: tensor(2.8013)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 14 Traning Loss: tensor(2.7950)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 15 Traning Loss: tensor(2.7889)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 16 Traning Loss: tensor(2.7828)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 17 Traning Loss: tensor(2.7768)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 18 Traning Loss: tensor(2.7710)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 19 Traning Loss: tensor(2.7652)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 20 Traning Loss: tensor(2.7595)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 21 Traning Loss: tensor(2.7539)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 22 Traning Loss: tensor(2.7484)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 23 Traning Loss: tensor(2.7430)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 24 Traning Loss: tensor(2.7377)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 25 Traning Loss: tensor(2.7324)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 26 Traning Loss: tensor(2.7273)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 27 Traning Loss: tensor(2.7223)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 28 Traning Loss: tensor(2.7173)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 29 Traning Loss: tensor(2.7125)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 30 Traning Loss: tensor(2.7077)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 31 Traning Loss: tensor(2.7031)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 32 Traning Loss: tensor(2.6985)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 33 Traning Loss: tensor(2.6940)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 34 Traning Loss: tensor(2.6896)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 35 Traning Loss: tensor(2.6853)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 36 Traning Loss: tensor(2.6811)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 37 Traning Loss: tensor(2.6770)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 38 Traning Loss: tensor(2.6730)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 39 Traning Loss: tensor(2.6690)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 40 Traning Loss: tensor(2.6652)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 41 Traning Loss: tensor(2.6614)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 42 Traning Loss: tensor(2.6577)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 43 Traning Loss: tensor(2.6541)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 44 Traning Loss: tensor(2.6506)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 45 Traning Loss: tensor(2.6472)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 46 Traning Loss: tensor(2.6439)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 47 Traning Loss: tensor(2.6406)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 48 Traning Loss: tensor(2.6374)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 49 Traning Loss: tensor(2.6343)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 50 Traning Loss: tensor(2.6313)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 51 Traning Loss: tensor(2.6284)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 52 Traning Loss: tensor(2.6255)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 53 Traning Loss: tensor(2.6228)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 54 Traning Loss: tensor(2.6200)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 55 Traning Loss: tensor(2.6174)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 56 Traning Loss: tensor(2.6149)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 57 Traning Loss: tensor(2.6124)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 58 Traning Loss: tensor(2.6100)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 59 Traning Loss: tensor(2.6076)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 60 Traning Loss: tensor(2.6054)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
#

# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6777 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6778 Traning Loss: tensor(0.0012)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6779 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6780 Traning Loss: tensor(0.0011)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6781 Traning Loss: tensor(0.0008)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6782 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6783 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6784 Traning Loss: tensor(0.0012)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6785 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6786 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6787 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6788 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6789 Traning Loss: tensor(0.0009)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6790 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6791 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6792 Traning Loss: tensor(0.0009)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6793 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6794 Traning Loss: tensor(0.0011)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6795 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6796 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6797 Traning Loss: tensor(0.0016)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6798 Traning Loss: tensor(0.0014)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6799 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6800 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6801 Traning Loss: tensor(0.0009)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6802 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6803 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6804 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6805 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6806 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6807 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6808 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6809 Traning Loss: tensor(0.0010)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6810 Traning Loss: tensor(0.0010)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6811 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6812 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6813 Traning Loss: tensor(0.0011)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6814 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6815 Traning Loss: tensor(0.0016)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6816 Traning Loss: tensor(0.0007)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6817 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6818 Traning Loss: tensor(0.0008)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6819 Traning Loss: tensor(0.0013)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6820 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6821 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6822 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6823 Traning Loss: tensor(0.0005)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6824 Traning Loss: tensor(0.0006)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6825 Traning Loss: tensor(0.0011)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# 6826 Traning Loss: tensor(0.0019)
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# torch.Size([500, 1]) torch.Size([500, 1])
# torch.Size([500, 2])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 32
#      28 # Combining the loss functions
#      29 loss = mse_u + mse_f
# ---> 32 loss.backward() # This is for computing gradients using backward propagation
#      33 optimizer.step() # This is equivalent to : theta_new = theta_old - alpha * derivative of J w.r.t theta
#      35 with torch.autograd.no_grad():
#
# File c:\Users\xowls\anaconda3\lib\site-packages\torch\_tensor.py:396, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     387 if has_torch_function_unary(self):
#     388     return handle_torch_function(
#     389         Tensor.backward,
#     390         (self,),
#    (...)
#     394         create_graph=create_graph,
#     395         inputs=inputs)
# --> 396 torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File c:\Users\xowls\anaconda3\lib\site-packages\torch\autograd\__init__.py:173, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     168     retain_graph = create_graph
#     170 # The reason we repeat same the comment below is that
#     171 # some Python versions print out the first line of a multi-line function
#     172 # calls in the traceback and some print out the last line
# --> 173 Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175     allow_unreachable=True, accumulate_grad=True)
#
# KeyboardInterrupt:

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np

fig = plt.figure()
ax = fig.gca(projection='3d')

x=np.arange(0,2,0.02)
t=np.arange(0,1,0.02)
ms_x, ms_t = np.meshgrid(x, t)
## Just because meshgrid is used, we need to do the following adjustment
x = np.ravel(ms_x).reshape(-1,1)
t = np.ravel(ms_t).reshape(-1,1)

pt_x = Variable(torch.from_numpy(x).float(), requires_grad=True).to(device)
pt_t = Variable(torch.from_numpy(t).float(), requires_grad=True).to(device)
pt_u = net(pt_x,pt_t)
u=pt_u.data.cpu().numpy()
ms_u = u.reshape(ms_x.shape)

surf = ax.plot_surface(ms_x,ms_t,ms_u, cmap=cm.coolwarm,linewidth=0, antialiased=False)
             
             

ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
# Save Model
torch.save(net.state_dict(), "model_uxt.pt")
